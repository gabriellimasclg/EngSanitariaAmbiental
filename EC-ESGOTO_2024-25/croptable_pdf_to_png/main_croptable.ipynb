# %% [markdown]
# Este script recorta a tabela que está em um pdf branco e converte em jpg na qualidade máxima. Basta inserir a pasta de entrada com os pdfs e a pasta de saída.

# %%
import import_ipynb
from function_croptable import crop_pdf_to_table

# Defina os caminhos para a pasta de entrada e saída
input_folder = r'C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG' #onde tem os PDFs
output_folder = r"C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG\output" #onde vão sair as figuras
crop_pdf_to_table(input_folder, output_folder, zoom=4.0, quality=100)
# Out:
# tabela_PGAlt_eeb_alt1.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG\output\tabela_PGAlt_eeb_alt1.jpg
#
# tabela_PGAlt_eeb_alt2.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG\output\tabela_PGAlt_eeb_alt2.jpg
#
# tabela_PGAlt_eeb_alt3.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG\output\tabela_PGAlt_eeb_alt3.jpg
#
# tabela_PGAlt_taxa.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG\output\tabela_PGAlt_taxa.jpg
#
# tabela_PGBacias.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Nova Santa Rita\PG\output\tabela_PGBacias.jpg
#
# Processing complete.
