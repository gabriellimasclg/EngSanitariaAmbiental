# %% [markdown]
# Este script recorta a tabela que está em um pdf branco e converte em jpg na qualidade máxima. Basta inserir a pasta de entrada com os pdfs e a pasta de saída.

# %%
#!pip install pymupdf pillow opencv-python numpy

# %%
import import_ipynb
from function_croptable import crop_pdf_to_table

# Defina os caminhos para a pasta de entrada e saída
input_folder = r'C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas' #onde tem os PDFs
output_folder = r"C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output" #onde vão sair as figuras
crop_pdf_to_table(input_folder, output_folder, zoom=4.0, quality=100)
# Out:
# tabela_PGAlt_eeb_t2.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output\tabela_PGAlt_eeb_t2.jpg
#
# tabela_PGAlt_taxa_t2.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output\tabela_PGAlt_taxa_t2.jpg
#
# tabela_PGBacias_t2.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output\tabela_PGBacias_t2.jpg
#
# tabela_sesexistenteEEB_t1.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output\tabela_sesexistenteEEB_t1.jpg
#
# tabela_sesexistenteETE_t1.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output\tabela_sesexistenteETE_t1.jpg
#
# tabela_sesexistente_t1.jpg - C:\Users\gabriel.coimbra\Desktop\Meus arquivos\Tapes\PGs\tabelas\output\tabela_sesexistente_t1.jpg
#
# Processing complete.
