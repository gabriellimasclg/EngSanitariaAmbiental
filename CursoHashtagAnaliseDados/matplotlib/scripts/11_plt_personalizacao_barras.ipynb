# %% [markdown]
# # Mais personalizações possíveis

# %% [markdown]
# ## Gráfico de barras para apresentação
#
# Considere que você tem as quantidades de produtos vendidos em uma loja. Faça um gráfico de barras horizontais.

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.bar(produtos, quantidades, color='green')

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.ylabel('Quantidade Vendida')
plt.xlabel('Produto')
plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades, color='green') #barh --> bar na h (horizontal)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.xlabel('Quantidade Vendida')
plt.ylabel('Produto')
plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=[max(quantidades) if x == max(quantidades) else '' for x in quantidades],
              padding=3, fontsize=10, fontweight='bold')

# retirando as bordas do gráfico
plt.box(False)

# retirando o eixo x
plt.xticks([])

# diminuindo os ticks do eixo y
plt.tick_params(axis='y', length=0)

# destacando a barra do produto com maior quantidade vendida
for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.2)

# título
plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
# explicando o zip do Python
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

print(zip(quantidades, produtos))
print(list(zip(quantidades, produtos)))
# Out:
# <zip object at 0x000001A37615D780>
# [(23, 'Produto A'), (45, 'Produto B'), (17, 'Produto C'), (30, 'Produto D'), (37, 'Produto E')]

# %%
print(sorted(zip(produtos, quantidades))) #sorted vai ordenar com base no primeiro item do zip
print(sorted(zip(quantidades, produtos)))
# Out:
# [('Produto A', 23), ('Produto B', 45), ('Produto C', 17), ('Produto D', 30), ('Produto E', 37)]
# [(17, 'Produto C'), (23, 'Produto A'), (30, 'Produto D'), (37, 'Produto E'), (45, 'Produto B')]

# %%
dados_ordenados = sorted(zip(quantidades, produtos))  # por quantidade
quantidades_ordenadas = [x[0] for x in dados_ordenados]
produtos_ordenados = [x[1] for x in dados_ordenados]

# %%
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.barh(produtos_ordenados, quantidades_ordenadas)

plt.bar_label(barras, labels=[max(quantidades_ordenadas) if x == max(quantidades_ordenadas) else '' for x in quantidades_ordenadas],
              padding=3, fontsize=10, fontweight='bold')

# retirando as bordas do gráfico
plt.box(False)

# retirando o eixo x
plt.xticks([])
plt.tick_params(axis='y', length=0)

# destacando a barra do produto com maior quantidade vendida
for i, barra in enumerate(barras):
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)):
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.2)


plt.title('Quantidade de Produtos Vendidos')

# caso queira inverter o eixo, descomente a linha abaixo
# plt.gca().invert_yaxis()

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.bar(produtos_ordenados, quantidades_ordenadas)

plt.bar_label(barras, labels=[max(quantidades_ordenadas) if x == max(quantidades_ordenadas) else '' for x in quantidades_ordenadas],
              padding=3, fontsize=10, fontweight='bold')

# retirando as bordas do gráfico
plt.box(False)

# retirando o eixo y
plt.yticks([])
plt.tick_params(axis='x', length=0)

# destacando a barra do produto com maior quantidade vendida
for i, barra in enumerate(barras):
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)):
        barras[i].set_color(plt.get_cmap('Pastel2').colors[1])
        barras[i].set_alpha(0.2)


plt.title('Quantidade de Produtos Vendidos')

# caso queira inverter o eixo, descomente a linha abaixo
# plt.gca().invert_xaxis()

plt.show()
