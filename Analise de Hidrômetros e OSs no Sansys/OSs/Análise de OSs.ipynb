# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import time
import pyproj
from geopy.geocoders import Nominatim

# %% [markdown]
# # Importar e organizar base de dados

# %%
#Inserir o caminho
caminho_geral = r''

#dar nomes adequados as bases de dados iniciais

log = pd.read_csv("logradouro.csv", encoding='latin1', delimiter='\t')
und = pd.read_csv("unidade_comercial.csv", encoding='latin1', delimiter='\t')

print(f"Colunas do arquivo de Logradouros {und.columns}")
print(f"Colunas do arquivo de Logradouros {log.columns}")
# Out:
# Colunas do arquivo de Logradouros Index(['Data de Solicitação', 'Número da OS', 'Código Logradouro', 'Endereço',
#        'Ponto de Referência', 'Bairro', 'Município', 'Matrícula',
#        'Situação Ligação Água', 'Serviço Solicitado', 'Serviço Executado',
#        'Setor Execução', 'Funcionário / Equipe', 'Localização', 'Hidrômetro',
#        'Grupo', 'Data de Execução', 'Data de Encerramento',
#        'Quantidade de Serviço Executado', 'Nome do Proprietário',
#        'Usuário Solicitante', 'Situação', 'Parecer Solicitação',
#        'Parecer Não Execução', 'Motivo Não Execução',
#        'Data Limite de Execução', 'Parecer Execução', 'Data de Cancelamento',
#        'Parecer Cancelamento', 'Data Final da Suspensão por Controle',
#        'Motivo da Suspensão por Controle', 'Parecer da Suspensão por Controle',
#        'Período de Suspensão por Controle (dias - horas:min:seg)',
#        'Data Final da Liberação', 'Parecer da Liberação'],
#       dtype='object')
# ...

# %% [markdown]
# Deve-se comparar as colunas, pegar as necessárias (e criar as que não tiver) e concatenar

# %% [markdown]
# Já tem: Matrícula;	Serviço; Data de Solicitação;	Endereço;

# %% [markdown]
# Criar: Rua; Bairro;	Número;	x; y; Latitude;	Longitude.

# %%
und['Rua','Número','x','y',] = np.nan
und[] = np.nan
und[] = np.nan
und[] = np.nan
und['Latitude'] = np.nan
und['Longitude'] = np.nan
und = und[['Matrícula','Categoria de serviço','Data de Solicitação','Endereço','Bairro','Número','Latitude','Longitude']]
